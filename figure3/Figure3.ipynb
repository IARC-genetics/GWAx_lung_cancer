# %% [markdown]
# # Plots for Figure 3
# ## bin plot

# %%
from plotly.subplots import make_subplots

import plotly.graph_objects as go
import plotly
fig = go.Figure()
fig.update_layout(plot_bgcolor='white' ) 

def SetColor(x):
    if(float(x) >= 1.54):
        return "red"
    elif(float(x) >= 0.1) & (float(x) < 1.54):
        return "#BBBBBB"

fig = make_subplots(rows=2, cols=1, shared_xaxes=True,
    vertical_spacing=0.1,)

#fig.update_layout(title={'text': title_plot,'x':0.5 , 'xanchor': 'center','yanchor': 'top' , 'font_color':"black"})
fig.update_xaxes(row=1 , col=1 ,title="Smoking Bin Ranking"  ,  range=[0 ,2010] , ticks="outside" , color='black', tickwidth=5, tickcolor='black', ticklen=10, showline=True, linewidth=5, linecolor='Black')
fig.update_xaxes(row=2 , col=1 , title="eQTL Bin Ranking",  range=[0 ,2010], ticks="outside"    , color='black', tickwidth=5, tickcolor='black', ticklen=10, showline=True, linewidth=5, linecolor='Black')
fig.update_yaxes(row=1 , col=1, title= "mean LC Z-stat", ticks="outside" , range=[0.9 ,3.5],zerolinecolor="black", showgrid = False, color='black',tickwidth=5, tickcolor='black', ticklen=10, showline=True, linewidth=5, linecolor='Black')
fig.update_yaxes(row=2 , col=1, title= "mean LC Z-stat", ticks="outside" , range=[0.9 ,2.5],zerolinecolor="black", showgrid = False, color='black',tickwidth=5, tickcolor='black', ticklen=10, showline=True, linewidth=5, linecolor='Black')
#fig.update_yaxes(ticks="outside", title="Mean Z-stat LC bin" ,color='black',tickwidth=5, tickcolor='black', ticklen=10, showline=True, linewidth=5, linecolor='Black')

fig.update_layout(font=dict(size=15 , color = "black") ) 
fig.add_trace(go.Scatter( name="Smoking Bins", mode="markers"  , x = smk["Nbin"].tolist(), y = smk["mean_values"].tolist(), showlegend=False ,opacity=1, marker_line_width=0.8, line=dict(color="black"), marker_color=list(map(SetColor, smk['mean_values']) )   ), row=1, col=1)
fig.add_trace(go.Scatter( name="eQTL Bins", mode="markers"  , x = eqtl["Nbin"].tolist(), y = eqtl["mean_values"].tolist(), showlegend=False ,opacity=1, marker_line_width=0.8, line=dict(color="black"), marker_color=list(map(SetColor, eqtl['mean_values'])) ) ,row =2 , col=1 )

fig.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="left",
    x=0.20 , font=dict(size=20)
))

fig.update_layout( plot_bgcolor='white',paper_bgcolor='white') 

#fig.update_layout(xaxis=dict(range=[1,2010]))
fig.write_image("bins.png",width=800, height=800, scale=10)
fig.show()

# %% [markdown]
# ## Forest plot

# %%
import plotly.io as mkimage
import plotly as py
import plotly.graph_objects as go
fig = go.Figure()
##### variable to be passed in
#SNP = "rs12345"
ORS = [1.28]
ORS_1 = [1.28 ]
ORS_2 = [1.12, 1.18,1.194 ]
ORS_3 = [1.216, 1.277,1.28 ,1.304 ]
ORS_4 = [1.179, 1.235, 1.251, 1.254 ]
STUDY_TABLE = ["Smoking PRS"," GW SNPs", "eQTL PRS","Combined PRS"]

TABLE_1 = ["65 GWS PRS"]
TABLE_2 = ["Smoking PRS(80)" , "eQTL PRS(961)" , "Combined (998)"]
TABLE_3 = ["Smoking PRS(100)" , "eQTL PRS(1000)" , "GWS_hits (65)" , "Combined(1149)"]
TABLE_4 = ["Smoking PRS(100)" , "eQTL PRS(1000)" , "GWS_hits (65) ", "Combined(1149)"]

STUDY_FOREST_Y = ["Combined PRS" ," GW SNPs (65 loci)", "eQTL PRS", "Smoking PRS"]
STUDY_FOREST_Y1 = ["Combined PRS" , "eQTL PRS", "Smoking PRS"]
Y_1 = [9]
Y_2 = [8.4,7.9,7.3]
Y_3 = [1.8, 1.2,0.7,0.1]
Y_4 = [5.6, 5.1, 4.5, 3.9]

STUDY_P_VALUES_1 = [4.29e-17]
STUDY_P_VALUES_2 = [7.17e-05, 1.63e-08, 1.36e-09]
STUDY_P_VALUES_3 = [1.88e-07, 4.28e-11, 1.41e-12, 1.77e-12]
STUDY_P_VALUES_4 = [2.40e-11, 1.45e-16, 4.29e-17, 3.95e-19]

UPPER_1 = [0.072]
UPPER_2 = [0.06,0.06,0.06,0.06]
UPPER_3 = [0.08,0.075,0.08,0.08]
UPPER_4 = [0.078,0.076,0.071,0.07]

LOWER_1 = [0.08]
LOWER_2 = [0.08,0.07,0.07,0.07, 0.07]
LOWER_3 = [0.08,0.07,0.07,0.07, 0.07]
LOWER_4 = [0.08,0.07,0.07,0.07, 0.07]


SNP_ORS_1 = ["1.28 [1.209-1.356]"]
SNP_ORS_2 = ["1.12 [1.06-1.188]" , "1.18 [1.114-1.249]", "1.194 [1.127-1.265]"]
SNP_ORS_3 = ["1.179 [1.108-1.254]" , "1.235 [1.16-1.25]", "1.251 [1.176-1.331]", "1.254 [1.177-1.335]"]
SNP_ORS_4 = ["1.216 [1.148-1.287]" , "1.277 [1.205-1.351]", "1.28 [1.209-1.356]", "1.304 [1.23-1.382]"]



fig.update_shapes(dict(xref='x', yref='y'))
fig.add_shape(type="line",x0=1.28, y0=-0.5, x1=1.28, y1=10,line=dict(color="black",width=1, dash="dot"), layer="below")
fig.update_shapes(dict(xref='x', yref='y'))
fig.add_shape(type="line",x0=1, y0=-0.5, x1=1, y1=10,line=dict(color="red",width=1,))



fig.add_trace(go.Table(domain=dict(x=[0, 0.5],
                y=[0.65, 0.97]), columnwidth = [300] ,columnorder=[0, 1, 2],header = dict(values = [['<b>Cohort</b>'],['<b>Odds Ratio (CI)</b>'],['<b>P-value</b>']],
                  line = dict(color='white'),
                  align = ['center'],
                  font = dict(color=['black'] * 5, size=10),
                  fill = dict(color='white')),cells=dict( height = 20, values=[TABLE_2, SNP_ORS_2 , STUDY_P_VALUES_2],line = dict(color='white') ,font = dict(color=['black'] * 5, size=10), fill =dict(color='white'))), )



fig.add_trace(go.Table(
    domain=dict(x=[0, 0.5],
                y=[0.6, 0.79]),
    columnwidth = [300] ,
    columnorder=[0, 1, 2],
    header = dict(height = 1,
                  line = dict(color='white'),
                  align = ['center'],
                  font = dict(color=['black'] * 5, size=12),
                  fill = dict(color='white')),
    cells=dict(height = 20, values=[TABLE_4, SNP_ORS_4 , STUDY_P_VALUES_4],line = dict(color='white') ,font = dict(color=['black'] * 5, size=10), fill =dict(color='white'))
) , ) 

fig.add_trace(go.Table(
    domain=dict(x=[0, 0.5],
                y=[0.3, 0.57]),
    columnwidth = [300] ,
    columnorder=[0, 1, 2],
    header = dict(height = 1,
                  line = dict(color='white'),
                  align = ['center'],
                  font = dict(color=['black'] * 5, size=12),
                  fill = dict(color='white')),
    cells=dict(height = 20, values=[TABLE_3, SNP_ORS_3 , STUDY_P_VALUES_3],line = dict(color='white') ,font = dict(color=['black'] * 5, size=10), fill =dict(color='white'))) , ) 


fig.add_trace(go.Scatter( 
        x=ORS_2, marker_size=10, showlegend=False, marker_symbol="diamond-x",marker_line_width=1,
        y=Y_2,marker_line_color="black" , line_color="black" ,
        mode='markers', error_x=dict(type='data',array=UPPER_2, visible=True, symmetric=True))) 
fig.add_trace(go.Scatter( 
        x=ORS_4, marker_size=10, showlegend=False, marker_symbol="diamond-x",marker_line_width=1,
        y=Y_3,marker_line_color="black" , line_color="black" ,
        mode='markers', error_x=dict(type='data',array=UPPER_3, visible=True, symmetric=True))) 
fig.add_trace(go.Scatter( 
        x=ORS_3, marker_size=10, showlegend=False, marker_symbol="diamond-x",marker_line_width=1,
        y=Y_4,marker_line_color="black" , line_color="black" ,
        mode='markers', error_x=dict(type='data',array=UPPER_4, visible=True, symmetric=True))) 
fig.add_annotation(text="<i><B>PRS of sub-GW significant variants</b></i>",
                  xref="paper", yref="paper",
                  x=0.08, y=1, showarrow=False)
fig.add_annotation(text="<i><b> PRS of GW and sub-GW significant variants </b></i>",
                  xref="paper", yref="paper",
                  x=0.05, y=0.80, showarrow=False)
fig.add_annotation(text="<i><b> PRS of GW and sub-GW significant variants after <br> adjustment for smoking status.</b></i>",
                  xref="paper", yref="paper",
                  x=0.0, y=0.58, showarrow=False)


fig.update_layout(yaxis_visible=False, yaxis_showticklabels=False)
fig.update_layout(barmode='group', plot_bgcolor='white',paper_bgcolor='white' , font_color="black", xaxis1=dict( domain=[0.45, 0.9] , anchor='y1' ,showticklabels=True, range=[0.95 ,1.4], tick0=0.9, dtick=0.05 ,ticks="outside", tickwidth=1, tickcolor='black', ticklen=5 , showline=True, linewidth=2, linecolor='black',title="Odds ratio") ,yaxis1=dict(domain=[0.38, 1] ,anchor='x1', hoverformat='.2f') , )
fig.write_image("forest.png",width=800, height=800,scale=10)
fig.show()
